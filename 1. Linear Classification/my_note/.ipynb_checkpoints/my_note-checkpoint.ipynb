# %% [markdown]
# # {Linear Classification}

# %% [markdown]
# # Today's Agenda
# ---
# * Review on Digital Image Processing and Recognation System
# * Review on Linear Classification
#      - Image Classifier
#      - SVM and Softmax Loss Function
# * Data Handling

# %% [markdown]
# ### Computer Vision Core
#
# ---
# <img src="assets/cv_core.PNG" style="width:500px"/>

# %% [markdown]
# ### Image Classification
#
# ---
# <img src="assets/image_classification.PNG" style="width:500px"/>

# %% [markdown]
# ### Problem and Challanges
#
# ---
#
# * Semantic Gap
# * Zoom, Angle
# * Illumination
# * Deformation
# * Occlusion
# * Background Clutter
# * Intraclass Variation

# %% [markdown]
# ### Image Classifieir Early Days
#
# ---
# * detect edges
# * Define rule to recognize
#
# <img src="assets/ic_earlydays.PNG" style="width:500px"/>
#
# * Unscalable Approach
#     - Only works on specific object
#     - Defferent object need different rule
# * Main Course:
#     - Availability of data
#     - Low-resolution grayscale image

# %% [markdown]
# ### Data-driven Approach
#
# ---
# * Collect dataset of images and labels
#     - The luxury of using data, availability of Internet
#
# <img src="assets/training_set.PNG" style="width:500px"/>
#
# * Use Machine Learning to train an image classifier
# * Evaluate the classifier on a withheld set of test images
#
# <img src="assets/mcl.PNG" style="width:500px"/>

# %% [markdown]
# #### # First Classifier: Nearest Neighbor!
#
# ---
# * Training Process
#     - Memorize all training images (data and labels)
#     - (easy)
# * Testing Process
#     - Use L1 or L2 (or other distance choices) distance to each and every training image, return label of the closest one
#     - L1 : Manhattan Distance
#     - L2 : Euclidean Distance
# * Training Speed?
#     - O(1)
# * Testing Speed?
#     - O(N)
#     - Linearly slower according to the size of training data
# * Contradict with what we want: efficient at test time
# * Neural Net flip this: expensive at training, cheap test evaluation (almost constant)
#
# <img src="assets/knn.PNG" style="width:500px"/>
#
# #### ## K-Nearest Neighbor
#
# * Majority vote of the labels
# * Offer better performance at test time
#
# <img src="assets/k-nn.PNG" style="width:500px"/>
#
# #### ## Distance Metric
#
# <img src="assets/distance_metric.PNG" style="width:500px"/>
#
# #### ## k-Nearest Neighbors - Hyperparameters
#
# * Choices about the algorithm that we set rather than learn
# * Very problem-dependent.
# * Must try them all out and see what works best.

# %% [markdown]
# ### Data Handling for Hyperparameter Tuning
#
# ---
# ### # Data Preparation
#
# <img src="assets/data_preparation.PNG" style="width:500px"/>
#
# #### ## Using Validation
# * Single Validation Split
# * Random Cross Validation
# * K-Fold Cross Validation
#
# #### ## K-Fold Cross-Validation
# * Useful incase of small training data! (not used too frequently in DL)
#
# <img src="assets/k-fold.PNG" style="width:500px"/>
#
# #### ## Types of Data
#
# * Train set
#     - Use to train the model
# * Validation set (dev set)
#     - Use to tune (find the best) Hyperparameters
# * Test set
#     - Proxy for generalization performance
#     - Should not use while observation
#     - Forget you even have it
#     - Use only very sparingly at the end
#         * To check how well the model in generalizing the unseen data point
#         * Evaluate on the test set only a single time, at the very end
#
# #### # Observing Data Split
# <img src="assets/observe_data.PNG" style="width:500px"/>
#
# ---
# ### # Data Preproccesing
# * Zero-centered data : Subtract the mean
# * Normalize : divide with standard deviation
# * Go further : PCA, Whitening
# * **Careful** : any preprocessing statistics (e.g. the data mean) must only be computed on the training data, and then applied to the validation / test data
#
# <img src="assets/data_preprocessing.PNG" style="width:500px"/>
#
# #### ## Data Preprocessing for Images
#
# * Center only for all train data
# * Substract the mean image (e.g. AlexNet)
#     - Mean Image = array[h, w, d]
# * Substract per-channel mean (e.g. VGGNet)
#     - Mean along each channel = 3 number
#
# <img src="assets/data_preprocessing.PNG" style="width:500px"/>

# %% [markdown]
# ### # Image Classifier: K-Nearest Neighbors
#
# ---
# * K-Nearest neighbor on images (pixel spaces) is never used T
#     * erible performance at test time.
#     * Distance metrics on level of whole images can be very unintuitive: **shifted image, messed up, illumination**
# * K-Nearest Neighbor is always used on feature space

# %% [markdown]
# ### # Course of Dimensionaly
#
# ---
# <img src="assets/dimension.PNG" style="width:500px"/>

# %% [markdown]
# ### # Computer Vision Before
#
# ---
# * Linear classification on Image Features,
#     - Not in pixel
#
# * Examples :
#     - Color (Hue) Histogram
#     - HOG/SIFT
#     - GIST
#     - LBP
#     - Texton
#     - SSIM
#
# <img src="assets/classicvsdl.PNG" style="width:650px"/>

# %% [markdown]
# ### Linear Classifier
#
# ---
# * Score Function
# <img src="assets/score_function.PNG" style="width:500px"/>

# %% [markdown]
# ### Review Logistic Regression (Binary Linear Classifier)
#
# ---
# ### # Logistic regression
#
# ---
# <img src="assets/logistic_regression.PNG" style="width:150px"/>
#
# * Weighted Sum to determine YES(1) or NO(0)
#     - Receive input from outside
#     - Multiplying by the weight connected to it
#     - Sum up all of them
#     - Limit output in the range [0-1]
# * If output total high, then class = close to YES!
# * Weight is a feature identifier
#     - a value that state the importance of the atribute assosiated with it
#     - if its input is important (to class 1), increase it
#
# ### # Linear Classifier
#
# ---
# <img src="assets/logistic_regression_multi.PNG" style="width:150px"/>
#
# * For multiclass classification, there will be a logistic regression for each class
#     - For 𝑑-dimensional input
#     - with 𝑐-class output,
#     - There will be 𝑐×𝑑 weight parameter
#
# * **Parametic Approach**
#
# <img src="assets/parameter_approach.PNG" style="width:500px"/>
#
# * Tweak weights (and bias) to maximize target class score and minimize the other scores
#
# #### ## Algebraic Viewpoint
#
# * **Parametic Approach**
#
# <img src="assets/parameter_approach1.PNG" style="width:500px"/>
#
# <img src="assets/parameter_approach2.PNG" style="width:500px"/>
#
# > reshap back wights inti image shape
#
# <img src="assets/image_reshape.PNG" style="width:300px"/>
#
# #### ## Visual Viewpoint
#
# * Linear classification is like forming a recognation template for each class
#
# <img src="assets/lc_vp.PNG" style="width:500px"/>
#
# <img src="assets/lc_vp1.PNG" style="width:500px"/>
#
# <img src="assets/lc_vp3.PNG" style="width:500px"/>
#
# #### ## Geometric View
#
# <img src="assets/gv.PNG" style="width:500px"/>
#
# <img src="assets/gv1.PNG" style="width:500px"/>
#
# #### ### Three Viewpoint
#
# <img src="assets/3viewpoint.PNG" style="width:700px"/>

# %% [markdown]
# ### Defining a Good Classsifier
#
# ---
#
# * Define a function that quantifying what it means to have a “good” W
# * Come up with a way of efficiently finding the parameters that minimize the loss function.

# %% [markdown]
# ### Loss Functions
#
# ---
#
# ### # Loss Score
#
# * Given a dataset of examples
# <img src="assets/pi1.PNG" style="width:100px"/>
# * Loss over the dataset is a sum of loss over examples
#     * Average of prediction error of each data point 𝐿_𝑖
# Loss over the dataset is a sum of loss over examples
# Average of prediction error of each data point 𝐿_𝑖
# <img src="assets/pic2.PNG" style="width:150px"/>
#
# ### # Scoring - Regression
#
# * The response variable is numeric or continuous
#     * L2 squared norm
# <img src="assets/pic2.PNG" style="width:150px"/>
# L1 norm of the difference
#     * Absolute error
# <img src="assets/pic2.PNG" style="width:150px"/>
#
# ### # Scoring - Classification
#
# * Separate  the dataset into classes belonging to the response variable
#     * Multiclass SVM Loss (Hinge loss)
# <img src="assets/pic3.PNG" style="width:200px"/>
#     * Softmax Loss (Cross-entropy loss)
# <img src="assets/pic4.PNG" style="width:150px"/>

# %% [markdown]
# ### Calculating Loss Multiclass SVM Loss
# **Hinge Loss**
#
# ---
# <img src="assets/pic5.PNG" style="width:500px"/>
#
# ---
# <img src="assets/p6.PNG" style="width:500px"/>
#
# ---
# <img src="assets/p7.PNG" style="width:500px"/>
#
# ---
# <img src="assets/p8.PNG" style="width:500px"/>

# %% [markdown]
# ### Calculating Loss Softmax Loss
# **Multinominal Logistic Loss**
#
# ---
# ### # Softmax score
#
# ---
# <img src="assets/p9.PNG" style="width:500px"/>
#
# ---
# <img src="assets/p10.PNG" style="width:500px"/>
#
# ---
# ### # Softmax Loss
#
# ---
# <img src="assets/p12.PNG" style="width:500px"/>
#
# ---
# <img src="assets/p11.PNG" style="width:500px"/>

# %% [markdown]
# ### Softmax Loss - Practical Issues
#
# ---
# <img src="assets/p13.PNG" style="width:500px"/>
#
# ---
# <img src="assets/p14.PNG" style="width:500px"/>
